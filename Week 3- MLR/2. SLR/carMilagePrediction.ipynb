# %%
import pandas as pd

# %%
dataset = pd.read_csv("carMilageDs.csv")
dataset
# Out:
#    Engine_Size_L (X)  MPG (Y)
# 0                1.2       38
# 1                1.4       36
# 2                1.6       34
# 3                1.8       32
# 4                2.0       30
# 5                2.2       28
# 6                2.4       27
# 7                2.6       25
# 8                2.8       24
# 9                3.0       22

# %%
independent =  dataset[['Engine_Size_L (X)']]
independent
# Out:
#    Engine_Size_L (X)
# 0                1.2
# 1                1.4
# 2                1.6
# 3                1.8
# 4                2.0
# 5                2.2
# 6                2.4
# 7                2.6
# 8                2.8
# 9                3.0

# %%
dependent = dataset[['MPG (Y)']]
dependent
# Out:
#    MPG (Y)
# 0       38
# 1       36
# 2       34
# 3       32
# 4       30
# 5       28
# 6       27
# 7       25
# 8       24
# 9       22

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test =  train_test_split(independent, dependent, test_size = 0.30, random_state=0)

# %%
x_train
# Out:
#    Engine_Size_L (X)
# 9                3.0
# 1                1.4
# 6                2.4
# 7                2.6
# 3                1.8
# 0                1.2
# 5                2.2

# %%
from sklearn.linear_model import LinearRegression
regressor = LinearRegression()
regressor.fit(x_train, y_train)
# Out:
# LinearRegression()

# %%
weight =  regressor.coef_
weight
# Out:
# array([[-8.9573991]])

# %%
bias = regressor.intercept_
bias
# Out:
# array([48.39686099])

# %%
y_pred = regressor.predict(x_test)
y_pred
# Out:
# array([[34.06502242],
#        [23.3161435 ],
#        [30.48206278]])

# %%
from sklearn.metrics import r2_score
r_score = r2_score(y_test, y_pred)
r_score
# Out:
# 0.9860998916760421

# %%
import pickle

# %%
fileName = "MilagePredictedModel.sav"

# %%
pickle.dump(regressor, open(fileName, 'wb'))

# %%
loaded_model = pickle.load(open("MilagePredictedModel.sav",'rb'))
result = loaded_model.predict([[1.4]])
result
# Out:
# C:\anaconda3\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([[35.85650224]])
