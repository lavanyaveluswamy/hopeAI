# %%
import pickle
loaded_sc = pickle.load(open("x_scaler.pkl", "rb"))
loaded_scy = pickle.load(open("y_scaler.pkl", "rb"))

preinput = loaded_sc.transform([[1300,12000,4000,0,1]])
preinput
# Out:
# C:\anaconda3\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# array([[-1.46754484, -4.33834816, -1.50743981, -0.5       ,  1.30088727]])

# %%
loaded_model = pickle.load(open("svmstartupIOP.sav", "rb"))
result =  loaded_model.predict(preinput)
result
# Out:
# array([-1.03086497])

# %%
result = loaded_scy.inverse_transform(result.reshape(-1,1))
result
# Out:
# array([[2.83398213e+09]])
